# %%
import pandas as pd
import sqlalchemy
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
import psycopg2
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from pathlib import Path

# %%
engine = create_engine(f'postgresql://root:Yonah19!@mypostgresdb.cdxrpdwcb1ik.us-west-2.rds.amazonaws.com/postgres')
conn = engine.connect()

# %%
Base=automap_base()
Base.prepare(conn,reflect=True)

# %%
session=Session(engine)

# %%
Base.classes.keys()
# Out:
# ['players_salary']

# %%
players_salary_class=Base.classes.players_salary

# %%
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['players_salary']

# %%
engine.execute('SELECT * FROM players_salary').fetchall()
columns = inspector.get_columns('players_salary')
for c in columns :
    print(c['name'], c['type'])
# Out:
# index INTEGER
# player_name VARCHAR
# salary INTEGER
# age INTEGER
# games_played NUMERIC
# minutes_played NUMERIC
# field_goal_percent NUMERIC
# three_point_percent NUMERIC
# two_point_percent NUMERIC
# effective_field_goal NUMERIC
# free_throw_percent NUMERIC
# total_rebounds NUMERIC
# assist NUMERIC
# steal NUMERIC
# blocking NUMERIC
# points NUMERIC

# %%
players_query = session.query(players_salary_class.index,players_salary_class.player_name,players_salary_class.salary,players_salary_class.age,players_salary_class.games_played,players_salary_class.minutes_played,players_salary_class.field_goal_percent,players_salary_class.three_point_percent,players_salary_class.two_point_percent,players_salary_class.effective_field_goal,players_salary_class.free_throw_percent,players_salary_class.total_rebounds,players_salary_class.assist,players_salary_class.steal,players_salary_class.blocking,players_salary_class.points)
players_df=pd.DataFrame(players_query,columns=['index','player_name','salary','age','games_played','minutes_played','field_goal_percent','three_point_percent','two_point_percent','effective_field_goal','free_throw_percent','total_rebounds','assist','steal','blocking','points'])
players_df
# Out:
#      index          player_name    salary  age games_played minutes_played  \
# 0        0        Stephen Curry  34682550   29        51.00        1631.00
# 1        1         LeBron James  33285709   33        82.00        3026.00
# 2        2         Paul Millsap  31269231   32        38.00        1143.00
# 3        3        Blake Griffin  29512900   28        38.67        1313.33
# 4        4           Kyle Lowry  28703704   31        78.00        2510.00
# ..     ...                  ...       ...  ...          ...            ...
# 417    448          Vander Blue     50000   25         5.00          45.00
# 418    449         Jamil Wilson     50000   27        15.00         274.00
# 419    450         Gian Clavell     50000   24         7.00          64.00
# 420    451        Rodney Purvis     46080   23        16.00         290.00
# 421    452  Xavier Rathan-Mayes     46080   23         5.00         118.00
#
#     field_goal_percent three_point_percent two_point_percent  \
# 0                 0.50                0.42              0.60
# 1                 0.54                0.37              0.60
# 2                 0.46                0.35              0.51
# 3                 0.44                0.35              0.48
# 4                 0.43                0.40              0.47
# ..                 ...                 ...               ...
# 417               0.20                0.00              0.33
# 418               0.47                0.43              0.61
# 419               0.33                0.40              0.00
# 420               0.33                0.25              0.40
# 421               0.29                0.07              0.39
#
#     effective_field_goal free_throw_percent total_rebounds  assist   steal  \
# 0                   0.62               0.92         261.00  310.00   80.00
# 1                   0.59               0.73         709.00  747.00  116.00
# 2                   0.51               0.70         245.00  105.00   39.00
# 3                   0.49               0.78         285.33  222.67   27.33
# 4                   0.55               0.85         434.00  537.00   85.00
# ..                   ...                ...            ...     ...     ...
# 417                 0.20               0.50           1.00    3.00    1.00
# 418                 0.64               0.50          32.00   10.00    5.00
# 419                 0.50               1.00           7.00    3.00    2.00
# 420                 0.39               0.87          27.00   17.00    3.00
# 421                 0.30               0.44           5.00   18.00    6.00
#
#     blocking   points
# 0       8.00  1346.00
# 1      71.00  2251.00
# 2      44.00   555.00
# 3      12.00   828.00
# 4      19.00  1267.00
# ..       ...      ...
# 417     0.00     3.00
# 418     8.00   105.00
# 419     0.00    20.00
# 420     3.00    96.00
# 421     3.00    29.00
#
# [422 rows x 16 columns]

# %%
players_df1= players_df.drop(columns=['salary'])
players_df1
# Out:
#      index          player_name  age games_played minutes_played  \
# 0        0        Stephen Curry   29        51.00        1631.00
# 1        1         LeBron James   33        82.00        3026.00
# 2        2         Paul Millsap   32        38.00        1143.00
# 3        3        Blake Griffin   28        38.67        1313.33
# 4        4           Kyle Lowry   31        78.00        2510.00
# ..     ...                  ...  ...          ...            ...
# 417    448          Vander Blue   25         5.00          45.00
# 418    449         Jamil Wilson   27        15.00         274.00
# 419    450         Gian Clavell   24         7.00          64.00
# 420    451        Rodney Purvis   23        16.00         290.00
# 421    452  Xavier Rathan-Mayes   23         5.00         118.00
#
#     field_goal_percent three_point_percent two_point_percent  \
# 0                 0.50                0.42              0.60
# 1                 0.54                0.37              0.60
# 2                 0.46                0.35              0.51
# 3                 0.44                0.35              0.48
# 4                 0.43                0.40              0.47
# ..                 ...                 ...               ...
# 417               0.20                0.00              0.33
# 418               0.47                0.43              0.61
# 419               0.33                0.40              0.00
# 420               0.33                0.25              0.40
# 421               0.29                0.07              0.39
#
#     effective_field_goal free_throw_percent total_rebounds  assist   steal  \
# 0                   0.62               0.92         261.00  310.00   80.00
# 1                   0.59               0.73         709.00  747.00  116.00
# 2                   0.51               0.70         245.00  105.00   39.00
# 3                   0.49               0.78         285.33  222.67   27.33
# 4                   0.55               0.85         434.00  537.00   85.00
# ..                   ...                ...            ...     ...     ...
# 417                 0.20               0.50           1.00    3.00    1.00
# 418                 0.64               0.50          32.00   10.00    5.00
# 419                 0.50               1.00           7.00    3.00    2.00
# 420                 0.39               0.87          27.00   17.00    3.00
# 421                 0.30               0.44           5.00   18.00    6.00
#
#     blocking   points
# 0       8.00  1346.00
# 1      71.00  2251.00
# 2      44.00   555.00
# 3      12.00   828.00
# 4      19.00  1267.00
# ..       ...      ...
# 417     0.00     3.00
# 418     8.00   105.00
# 419     0.00    20.00
# 420     3.00    96.00
# 421     3.00    29.00
#
# [422 rows x 15 columns]

# %%
for column in players_df1.columns:
    print(f'Column {column} has {players_df1[column].isnull().sum()} null values')
# Out:
# Column index has 0 null values
# Column player_name has 0 null values
# Column age has 0 null values
# Column games_played has 0 null values
# Column minutes_played has 0 null values
# Column field_goal_percent has 0 null values
# Column three_point_percent has 0 null values
# Column two_point_percent has 0 null values
# Column effective_field_goal has 0 null values
# Column free_throw_percent has 0 null values
# Column total_rebounds has 0 null values
# Column assist has 0 null values
# Column steal has 0 null values
# Column blocking has 0 null values
# Column points has 0 null values

# %%
players_df2=players_df1.drop(columns=['index'])

players_indexed=players_df2.set_index('player_name')
players_indexed
# Out:
#                      age games_played minutes_played field_goal_percent  \
# player_name
# Stephen Curry         29        51.00        1631.00               0.50
# LeBron James          33        82.00        3026.00               0.54
# Paul Millsap          32        38.00        1143.00               0.46
# Blake Griffin         28        38.67        1313.33               0.44
# Kyle Lowry            31        78.00        2510.00               0.43
# ...                  ...          ...            ...                ...
# Vander Blue           25         5.00          45.00               0.20
# Jamil Wilson          27        15.00         274.00               0.47
# Gian Clavell          24         7.00          64.00               0.33
# Rodney Purvis         23        16.00         290.00               0.33
# Xavier Rathan-Mayes   23         5.00         118.00               0.29
#
#                     three_point_percent two_point_percent  \
# player_name
# Stephen Curry                      0.42              0.60
# LeBron James                       0.37              0.60
# Paul Millsap                       0.35              0.51
# Blake Griffin                      0.35              0.48
# Kyle Lowry                         0.40              0.47
# ...                                 ...               ...
# Vander Blue                        0.00              0.33
# Jamil Wilson                       0.43              0.61
# Gian Clavell                       0.40              0.00
# Rodney Purvis                      0.25              0.40
# Xavier Rathan-Mayes                0.07              0.39
#
#                     effective_field_goal free_throw_percent total_rebounds  \
# player_name
# Stephen Curry                       0.62               0.92         261.00
# LeBron James                        0.59               0.73         709.00
# Paul Millsap                        0.51               0.70         245.00
# Blake Griffin                       0.49               0.78         285.33
# Kyle Lowry                          0.55               0.85         434.00
# ...                                  ...                ...            ...
# Vander Blue                         0.20               0.50           1.00
# Jamil Wilson                        0.64               0.50          32.00
# Gian Clavell                        0.50               1.00           7.00
# Rodney Purvis                       0.39               0.87          27.00
# Xavier Rathan-Mayes                 0.30               0.44           5.00
#
#                      assist   steal blocking   points
# player_name
# Stephen Curry        310.00   80.00     8.00  1346.00
# LeBron James         747.00  116.00    71.00  2251.00
# Paul Millsap         105.00   39.00    44.00   555.00
# Blake Griffin        222.67   27.33    12.00   828.00
# Kyle Lowry           537.00   85.00    19.00  1267.00
# ...                     ...     ...      ...      ...
# Vander Blue            3.00    1.00     0.00     3.00
# Jamil Wilson          10.00    5.00     8.00   105.00
# Gian Clavell           3.00    2.00     0.00    20.00
# Rodney Purvis         17.00    3.00     3.00    96.00
# Xavier Rathan-Mayes   18.00    6.00     3.00    29.00
#
# [422 rows x 13 columns]

# %%
players_scaled=StandardScaler().fit_transform(players_indexed)

# %%
pca=PCA(n_components=0.95)
players_pca=pca.fit_transform(players_scaled)
players_pca
# Out:
# array([[ 2.41027456, -0.01982885, -2.23245874, ...,  1.06872364,
#         -0.41357776,  0.12355535],
#        [ 7.14476693, -0.86339105, -0.02309243, ...,  2.27162259,
#          0.24987909, -1.0309758 ],
#        [-0.1288888 ,  0.49387991, -0.29288437, ...,  0.75408362,
#         -0.13852339,  0.32650617],
#        ...,
#        [-4.49031014, -3.76744282, -1.12616684, ...,  0.79784807,
#          3.47557049,  0.35934193],
#        [-3.7757958 , -1.46826125,  0.42840185, ...,  0.62495477,
#         -0.2860996 ,  0.00844027],
#        [-4.95351558, -0.91892358,  3.52675489, ...,  0.45686809,
#         -0.46909384, -0.07982083]])

# %%
tsne = TSNE(learning_rate=50)
#        [ 3.78173566e+00, -1.88469086e+01],
#        [ 6.10593700e+00, -2.52438774e+01],
#        [-5.93711281e+00, -1.41970778e+01],
#        [-3.42882156e+00, -2.31467438e+01],
#        [ 6.20253563e+00, -1.42456236e+01],
#        [-1.00110993e-01, -7.28882980e+00],
#        [-1.45101700e+01,  1.03421462e+00],
#        [ 5.12790442e+00, -1.69445515e+01],
#        [ 4.89864254e+00,  1.45479364e+01],
#        [ 4.59277153e+00, -2.16415215e+01],
#        [ 9.35816002e+00, -1.43565750e+01],
#        [ 4.25987577e+00, -2.07054710e+01],
#        [ 5.95429659e+00, -1.87678566e+01],
#        [ 4.76856661e+00, -2.66734753e+01],
#        [ 7.45256281e+00, -9.73876190e+00],
#        [-1.26942186e+01, -8.32043076e+00],
#        [-7.48691750e+00, -9.91147900e+00],
#        [ 1.21223888e+01, -2.40841618e+01],
#        [ 4.12933588e+00, -2.93567104e+01],
#        [-9.23893547e+00,  2.34786987e+00],
#        [-9.97525978e+00,  2.03311181e+00],
#        [-6.74886370e+00, -1.13879118e+01],
#        [-2.84090590e+00, -2.29880581e+01],
#        [-4.60640097e+00, -1.30446787e+01],
#        [-7.51195860e+00, -2.34742718e+01],
#        [-5.87095547e+00, -2.45889339e+01],
#        [-4.17661238e+00, -2.50723934e+01],
#        [ 1.18352880e+01, -2.52330322e+01],
#        [-4.12392807e+00, -1.12386227e+01],
#        [-1.27909002e+01, -1.15695543e+01],
#        [ 8.95087624e+00, -2.68855495e+01],
#        [ 4.68895626e+00, -2.80785885e+01],
#        [-7.44064283e+00, -1.71107330e+01],
#        [-8.73116589e+00, -2.13646107e+01],
#        [ 6.19136333e-01, -1.92842312e+01],
#        [-5.08494234e+00, -1.97395477e+01],
#        [ 1.21306667e+01, -2.57797508e+01],
#        [ 1.04754057e+01, -2.63245564e+01],
#        [ 4.98373127e+00, -2.99284077e+01],
#        [-1.16676807e+01, -1.20686579e+01],
#        [-7.12554979e+00, -2.57067204e+01],
#        [ 1.89106929e+00, -2.55306301e+01],
#        [ 6.24880934e+00, -2.93494987e+01]], dtype=float32)

# %%
tsne_array.shape
# Out:
# (422, 2)

# %%
x=tsne_array[:,0]
y=tsne_array[:,1]

# %%
plt.scatter(x,y,c=players_df['salary'])
plt.savefig('../images/unsupervised_cluster.png')
plt.show()

# %%
inertia=[]
k=list(range(1,11))

for i in k:
    kmeans=KMeans(n_clusters=i, random_state=0)
    kmeans.fit(players_indexed)
    inertia.append(kmeans.inertia_)
    
    
elbow_graph={'k':k, "inertia":inertia}
elbow_df=pd.DataFrame(elbow_graph)
elbow_df
# Out:
# C:\Users\Nate\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
#     k       inertia
# 0   1  3.769556e+08
# 1   2  1.211072e+08
# 2   3  6.958134e+07
# 3   4  4.780406e+07
# 4   5  3.536843e+07
# 5   6  2.996310e+07
# 6   7  2.582061e+07
# 7   8  2.325717e+07
# 8   9  2.162983e+07
# 9  10  2.032441e+07

# %%
plt.plot(elbow_df['k'],elbow_df['inertia'])
plt.xticks(range(1,11))
plt.xlabel('# of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.savefig('../images/elbow_curve.png')
plt.show()
